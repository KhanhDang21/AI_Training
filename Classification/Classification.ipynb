# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier

# %% [markdown]
# Preprocessing

# %%
data = pd.read_csv('Train_samsung.csv')
df = data.copy()
display(df)
# Out:
#          X1   X2   X3            X4   X5     X6      X7     X8     X9  X10  \
# 0      Male  Yes    0      Graduate   No   6000  2250.0  265.0  360.0  NaN
# 1      Male  Yes    0      Graduate   No   2958  2900.0  131.0  360.0  1.0
# 2      Male  Yes    2      Graduate   No   6250  1695.0  210.0  360.0  1.0
# 3      Male  Yes    0      Graduate   No   2083  3150.0  128.0  360.0  1.0
# 4      Male   No    0      Graduate   No   4166     0.0   98.0  360.0  0.0
# ..      ...  ...  ...           ...  ...    ...     ...    ...    ...  ...
# 486    Male  Yes    2  Not Graduate  Yes   1875  1875.0   97.0  360.0  1.0
# 487    Male  Yes    2      Graduate   No  11417  1126.0  225.0  360.0  1.0
# 488  Female   No    0      Graduate   No   3237     0.0   30.0  360.0  1.0
# 489  Female  NaN  NaN      Graduate   No  10047     0.0    NaN  240.0  1.0
# 490    Male  Yes  NaN      Graduate   No  13650     0.0    NaN  360.0  1.0
#
#            X11 Class
# 0    Semiurban     N
# 1    Semiurban     Y
# 2    Semiurban     Y
# 3    Semiurban     Y
# 4    Semiurban     N
# ..         ...   ...
# 486  Semiurban     Y
# 487      Urban     Y
# 488      Urban     Y
# 489  Semiurban     Y
# 490      Urban     Y
#
# [491 rows x 12 columns]

# %%
display(df.isna().sum())
# Out:
# X1       12
# X2        1
# X3       11
# X4        0
# X5       24
# X6        0
# X7        0
# X8       16
# X9       12
# X10      40
# X11       0
# Class     0
# dtype: int64

# %% [markdown]
# Fill data missing

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col].fillna(df[col].mode()[0], inplace = True)
    else:
        df[col].fillna(round(df[col].mean()), inplace = True)
display(df)
# Out:
# C:\Users\84395\AppData\Local\Temp\ipykernel_20180\4257533361.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\84395\AppData\Local\Temp\ipykernel_20180\4257533361.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(round(df[col].mean()), inplace = True)
#          X1   X2 X3            X4   X5     X6      X7     X8     X9  X10  \
# 0      Male  Yes  0      Graduate   No   6000  2250.0  265.0  360.0  1.0
# 1      Male  Yes  0      Graduate   No   2958  2900.0  131.0  360.0  1.0
# 2      Male  Yes  2      Graduate   No   6250  1695.0  210.0  360.0  1.0
# 3      Male  Yes  0      Graduate   No   2083  3150.0  128.0  360.0  1.0
# 4      Male   No  0      Graduate   No   4166     0.0   98.0  360.0  0.0
# ..      ...  ... ..           ...  ...    ...     ...    ...    ...  ...
# 486    Male  Yes  2  Not Graduate  Yes   1875  1875.0   97.0  360.0  1.0
# 487    Male  Yes  2      Graduate   No  11417  1126.0  225.0  360.0  1.0
# 488  Female   No  0      Graduate   No   3237     0.0   30.0  360.0  1.0
# 489  Female  Yes  0      Graduate   No  10047     0.0  149.0  240.0  1.0
# 490    Male  Yes  0      Graduate   No  13650     0.0  149.0  360.0  1.0
#
#            X11 Class
# 0    Semiurban     N
# 1    Semiurban     Y
# 2    Semiurban     Y
# 3    Semiurban     Y
# 4    Semiurban     N
# ..         ...   ...
# 486  Semiurban     Y
# 487      Urban     Y
# 488      Urban     Y
# 489  Semiurban     Y
# 490      Urban     Y
#
# [491 rows x 12 columns]

# %%
display(df.isna().sum())
# Out:
# X1       0
# X2       0
# X3       0
# X4       0
# X5       0
# X6       0
# X7       0
# X8       0
# X9       0
# X10      0
# X11      0
# Class    0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = LabelEncoder().fit_transform(df[col])
display(df)
# Out:
#      X1  X2  X3  X4  X5     X6      X7     X8     X9  X10  X11  Class
# 0     1   1   0   0   0   6000  2250.0  265.0  360.0  1.0    1      0
# 1     1   1   0   0   0   2958  2900.0  131.0  360.0  1.0    1      1
# 2     1   1   2   0   0   6250  1695.0  210.0  360.0  1.0    1      1
# 3     1   1   0   0   0   2083  3150.0  128.0  360.0  1.0    1      1
# 4     1   0   0   0   0   4166     0.0   98.0  360.0  0.0    1      0
# ..   ..  ..  ..  ..  ..    ...     ...    ...    ...  ...  ...    ...
# 486   1   1   2   1   1   1875  1875.0   97.0  360.0  1.0    1      1
# 487   1   1   2   0   0  11417  1126.0  225.0  360.0  1.0    2      1
# 488   0   0   0   0   0   3237     0.0   30.0  360.0  1.0    2      1
# 489   0   1   0   0   0  10047     0.0  149.0  240.0  1.0    1      1
# 490   1   1   0   0   0  13650     0.0  149.0  360.0  1.0    2      1
#
# [491 rows x 12 columns]

# %%
df.describe(include = 'all')
# Out:
#                X1          X2          X3          X4          X5  \
# count  491.000000  491.000000  491.000000  491.000000  491.000000
# mean     0.810591    0.635438    0.729124    0.221996    0.136456
# std      0.392233    0.481798    1.009115    0.416012    0.343622
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    3.000000    1.000000    1.000000
#
#                  X6            X7          X8          X9         X10  \
# count    491.000000    491.000000  491.000000  491.000000  491.000000
# mean    5502.645621   1676.488635  148.731161  340.276986    0.857434
# std     5932.951396   3177.641499   86.274982   66.874636    0.349986
# min      150.000000      0.000000   17.000000   12.000000    0.000000
# 25%     2918.500000      0.000000  102.500000  360.000000    1.000000
# 50%     3900.000000   1126.000000  130.000000  360.000000    1.000000
# 75%     5938.000000   2333.000000  165.000000  360.000000    1.000000
# max    81000.000000  41667.000000  700.000000  480.000000    1.000000
#
#              X11       Class
# count  491.00000  491.000000
# mean     1.03666    0.696538
# std      0.78160    0.460222
# min      0.00000    0.000000
# 25%      0.00000    0.000000
# 50%      1.00000    1.000000
# 75%      2.00000    1.000000
# max      2.00000    1.000000

# %% [markdown]
# Setup model

# %%
target = 'Class'
x = df.drop(target, axis = 1)
y = df[target]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 246)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# Training model

# %%
model = RandomForestClassifier(n_estimators = 200, criterion = 'entropy')
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %% [markdown]
# Review model

# %%
y_pred = model.predict(x_test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("F1 score: ", f1_score(y_test, y_pred, average = 'weighted'))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  0.898989898989899
# F1 score:  0.8952379431831485
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.72      0.81        29
#            1       0.89      0.97      0.93        70
#
#     accuracy                           0.90        99
#    macro avg       0.90      0.85      0.87        99
# weighted avg       0.90      0.90      0.90        99
